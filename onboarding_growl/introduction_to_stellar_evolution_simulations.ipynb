# %% [markdown]
# ### Step 1: Download data
# see instructions below for the specific dataset we are working with. Replace with other data if needed

# %% [markdown]
# In the example here we will download data from:
#  - label: van Son et al. (2022)
#  - paper link: https://arxiv.org/pdf/2209.03385
#  - code: COMPAS
#  - method paper code: https://arxiv.org/pdf/2109.10352
#  - download instructions:
#       - go to https://doi.org/10.5281/zenodo.7612755,
#       - download `COMPAS_Output_wWeights.tar.gz' (3GB).
#       - unzip the file to obtain the 'COMPAS_Output_wWeights.h5'  file
#  - credit data: https://zenodo.org/records/7612755 and https://arxiv.org/pdf/2209.03385

# %%
datafile_loc  = '/Users/floorbroekgaarden/Downloads/vanSon_2022'
datafile_name = 'COMPAS_Output_wWeights.h5'
